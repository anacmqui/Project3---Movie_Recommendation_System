# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebastiao199/Project3MRS/blob/main/name_basics_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
name_basics = pd.read_csv('https://datasets.imdbws.com/name.basics.tsv.gz', sep = '\t')

name_basics.head(20)

#This database is about the person working in the movie industries : actors/director/music person/writer info. 
# There are 12005705 rows and 6 columns : ALL OBJECTS TYPE

# Weird columns : nconst and knowForTitles 
# Top primary profession : actor 
# Don't know how to interpret the nunique query 
# name_basics.isna().sum : weird result

    # TO UNDERSTAND THE COLUMNS: 
#nconst (string) - alphanumeric unique identifier of the name/person
#primaryName (string)– name by which the person is most often credited
#birthYear – in YYYY format
# deathYear – in YYYY format if applicable, else '\N'
#primaryProfession (array of strings)– the top-3 professions of the person
#knownForTitles (array of tconsts) – titles the person is known for

    # WHAT WE SHOULD KEEP / DELETE
# We should keep : nconst, primary Name,  primaryProfession, knowForTitles columns
# Delete: birthYear and deathYear
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm0000001         Fred Astaire      1899      1987
# 1   nm0000002        Lauren Bacall      1924      2014
# 2   nm0000003      Brigitte Bardot      1934        \N
# 3   nm0000004         John Belushi      1949      1982
# 4   nm0000005       Ingmar Bergman      1918      2007
# 5   nm0000006       Ingrid Bergman      1915      1982
# 6   nm0000007      Humphrey Bogart      1899      1957
# 7   nm0000008        Marlon Brando      1924      2004
# 8   nm0000009       Richard Burton      1925      1984
# 9   nm0000010         James Cagney      1899      1986
# 10  nm0000011          Gary Cooper      1901      1961
# 11  nm0000012          Bette Davis      1908      1989
# 12  nm0000013            Doris Day      1922      2019
# 13  nm0000014  Olivia de Havilland      1916      2020
# 14  nm0000015           James Dean      1931      1955
# 15  nm0000016      Georges Delerue      1925      1992
# ...

# %%
#name_basics.info()

# %%
name_basics.describe()
# Out:
#            nconst primaryName birthYear deathYear primaryProfession  \
# count    12005705    12005704  12005705  12005705           9415758
# unique   12005705     9341421       516       452             20955
# top     nm0000001        Alex        \N        \N             actor
# freq            1         379  11441936  11798501           2134072
#
#        knownForTitles
# count        12005705
# unique        4970073
# top                \N
# freq          2128221

# %%
name_basics.nunique()
# Out:
# nconst               12005705
# primaryName           9341421
# birthYear                 516
# deathYear                 452
# primaryProfession       20955
# knownForTitles        4970073
# dtype: int64

# %%
name_basics.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of           nconst  primaryName  birthYear  deathYear  primaryProfession  \
# 0          False        False      False      False              False
# 1          False        False      False      False              False
# 2          False        False      False      False              False
# 3          False        False      False      False              False
# 4          False        False      False      False              False
# ...          ...          ...        ...        ...                ...
# 12005700   False        False      False      False              False
# 12005701   False        False      False      False               True
# 12005702   False        False      False      False              False
# 12005703   False        False      False      False              False
# 12005704   False        False      False      False               True
#
#           knownForTitles
# 0                  False
# ...

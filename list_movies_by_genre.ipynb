# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebastiao199/Project3MRS/blob/main/list_movies_by_genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %%
df_titlebasics = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', sep = '\t')

# Contains the following information for titles:
# tconst (string) - alphanumeric unique identifier of the title // Interesting. Primary Key?
# titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc) // Interesting, maybe worths deleting the ones that are not the title type = "movie"
# primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release // Interesting
# originalTitle (string) - original title, in the original language // Drop (?)
# isAdult (boolean) - 0: non-adult title; 1: adult title // Interesting, but needs to be cleaned, there are some non booleans value.
# startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year // Interesting
# endYear (YYYY) – TV Series end year. ‘\N’ for all other title types // Drop (?), the ones with end year might be tvseries.
# runtimeMinutes – primary runtime of the title, in minutes // Interesting, maybe worths deleting the ones that are less than 60min taking in consideration the purpose are just movies.
# genres (string array) – includes up to three genres associated with the title // Interesting, there's interest values.
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_titlebasics.head(20)
# Out:
#        tconst titleType                                 primaryTitle  \
# 0   tt0000001     short                                   Carmencita
# 1   tt0000002     short                       Le clown et ses chiens
# 2   tt0000003     short                               Pauvre Pierrot
# 3   tt0000004     short                                  Un bon bock
# 4   tt0000005     short                             Blacksmith Scene
# 5   tt0000006     short                            Chinese Opium Den
# 6   tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     movie                                   Miss Jerry
# 9   tt0000010     short                          Leaving the Factory
# 10  tt0000011     short                      Akrobatisches Potpourri
# 11  tt0000012     short                       The Arrival of a Train
# 12  tt0000013     short  The Photographical Congress Arrives in Lyon
# 13  tt0000014     short                          The Waterer Watered
# 14  tt0000015     short                          Autour d'une cabine
# 15  tt0000016     short                        Boat Leaving the Port
# 16  tt0000017     short                     Italienischer Bauerntanz
# 17  tt0000018     short                         Das boxende Känguruh
# 18  tt0000019     short                             The Clown Barber
# 19  tt0000020     short                               The Derby 1895
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# 1                              Le clown et ses chiens       0      1892
# 2                                      Pauvre Pierrot       0      1892
# 3                                         Un bon bock       0      1892
# 4                                    Blacksmith Scene       0      1893
# 5                                   Chinese Opium Den       0      1894
# 6         Corbett and Courtney Before the Kinetograph       0      1894
# 7              Edison Kinetoscopic Record of a Sneeze       0      1894
# 8                                          Miss Jerry       0      1894
# 9                 La sortie de l'usine Lumière à Lyon       0      1895
# 10                            Akrobatisches Potpourri       0      1895
# 11                   L'arrivée d'un train à La Ciotat       0      1896
# 12  Le débarquement du congrès de photographie à Lyon       0      1895
# 13                                  L'arroseur arrosé       0      1895
# 14                                Autour d'une cabine       0      1894
# 15                             Barque sortant du port       0      1895
# 16                           Italienischer Bauerntanz       0      1895
# 17                               Das boxende Känguruh       0      1895
# 18                                   The Clown Barber       0      1898
# 19                                     The Derby 1895       0      1895
#
#    endYear runtimeMinutes                    genres
# 0       \N              1         Documentary,Short
# 1       \N              5           Animation,Short
# 2       \N              4  Animation,Comedy,Romance
# 3       \N             12           Animation,Short
# 4       \N              1              Comedy,Short
# 5       \N              1                     Short
# 6       \N              1               Short,Sport
# 7       \N              1         Documentary,Short
# 8       \N             45                   Romance
# 9       \N              1         Documentary,Short
# 10      \N              1         Documentary,Short
# 11      \N              1         Documentary,Short
# 12      \N              1         Documentary,Short
# 13      \N              1              Comedy,Short
# 14      \N              2           Animation,Short
# 15      \N              1         Documentary,Short
# 16      \N              1         Documentary,Short
# 17      \N              1                     Short
# 18      \N             \N              Comedy,Short
# 19      \N              1   Documentary,Short,Sport

# %%
df_titlebasics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9320186 entries, 0 to 9320185
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 640.0+ MB

# %%
df_titlebasics.describe()
# Out:
#            tconst  titleType  primaryTitle originalTitle  isAdult startYear  \
# count     9320186    9320186       9320175       9320175  9320186   9320186
# unique    9320186         11       4268462       4289109       11       151
# top     tt0000001  tvEpisode  Episode #1.1  Episode #1.1        0        \N
# freq            1    7033369         45574         45574  8967349   1247405
#
#         endYear runtimeMinutes   genres
# count   9320186        9320186  9320176
# unique       96            878     2330
# top          \N             \N    Drama
# freq    9222490        6793573  1058209

# %%
df_titlebasics.nunique()
#isAdult has 11 unique values, when supposely is boolean
#runtimeMinutes < 60 min might not make sense
# Out:
# tconst            9320186
# titleType              11
# primaryTitle      4268462
# originalTitle     4289109
# isAdult                11
# startYear             151
# endYear                96
# runtimeMinutes        878
# genres               2330
# dtype: int64

# %%
df_titlebasics['genres'].unique()
# Out:
# array(['Documentary,Short', 'Animation,Short', 'Animation,Comedy,Romance',
#        ..., 'Biography,Crime,Music', 'Mystery,Reality-TV,Thriller',
#        'Musical,Reality-TV,Talk-Show'], dtype=object)

# %%
df_titlebasics['genres'].unique()
# Out:
# array(['Documentary,Short', 'Animation,Short', 'Animation,Comedy,Romance',
#        ..., 'Biography,Crime,Music', 'Mystery,Reality-TV,Thriller',
#        'Musical,Reality-TV,Talk-Show'], dtype=object)

# %%
df_titlebasics['titleType'].isna().sum()
# Out:
# 0

# %%
# df_titlebasics.groupby('genres')['primaryTitle'].sum()

# %%
df_titlebasics['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvMiniSeries', 'tvShort', 'tvMovie', 'tvSeries',
#        'tvEpisode', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
movies = df_titlebasics[df_titlebasics['titleType'] == 'movie']
movies.reset_index()
# movies.groupby('genres').originalTitle
# Out:
#           index     tconst titleType  \
# 0             8  tt0000009     movie
# 1           498  tt0000502     movie
# 2           570  tt0000574     movie
# 3           587  tt0000591     movie
# 4           610  tt0000615     movie
# ...         ...        ...       ...
# 626223  9346728  tt9916622     movie
# 626224  9346755  tt9916680     movie
# 626225  9346767  tt9916706     movie
# 626226  9346778  tt9916730     movie
# 626227  9346788  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Miss Jerry
# 1                                                Bohemios
# 2                             The Story of the Kelly Gang
# 3                                        The Prodigal Son
# 4                                      Robbery Under Arms
# ...                                                   ...
# 626223        Rodolpho Teóphilo - O Legado de um Pioneiro
# 626224  De la ilusión al desconcierto: cine colombiano...
# 626225                                    Dankyavar Danka
# 626226                                             6 Gunn
# 626227                     Chico Albuquerque - Revelações
#
#                                             originalTitle isAdult startYear  \
# 0                                              Miss Jerry       0      1894
# 1                                                Bohemios       0      1905
# 2                             The Story of the Kelly Gang       0      1906
# 3                                       L'enfant prodigue       0      1907
# 4                                      Robbery Under Arms       0      1907
# ...                                                   ...     ...       ...
# 626223        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 626224  De la ilusión al desconcierto: cine colombiano...       0      2007
# 626225                                    Dankyavar Danka       0      2013
# 626226                                             6 Gunn       0      2017
# 626227                     Chico Albuquerque - Revelações       0      2013
#
#        endYear runtimeMinutes                      genres
# 0           \N             45                     Romance
# 1           \N            100                          \N
# 2           \N             70  Action,Adventure,Biography
# 3           \N             90                       Drama
# 4           \N             \N                       Drama
# ...        ...            ...                         ...
# 626223      \N             57                 Documentary
# 626224      \N            100                 Documentary
# 626225      \N             \N                      Comedy
# 626226      \N            116                          \N
# 626227      \N             49                 Documentary
#
# [626228 rows x 10 columns]

# %%
movies.info
# Out:
# <bound method DataFrame.info of             tconst titleType  \
# 8        tt0000009     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 610      tt0000615     movie
# ...            ...       ...
# 9320076  tt9916622     movie
# 9320103  tt9916680     movie
# 9320115  tt9916706     movie
# 9320126  tt9916730     movie
# 9320136  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 610                                     Robbery Under Arms
# ...                                                    ...
# 9320076        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9320103  De la ilusión al desconcierto: cine colombiano...
# 9320115                                    Dankyavar Danka
# 9320126                                             6 Gunn
# 9320136                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 610                                     Robbery Under Arms       0      1907
# ...                                                    ...     ...       ...
# 9320076        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9320103  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9320115                                    Dankyavar Danka       0      2013
# 9320126                                             6 Gunn       0      2017
# 9320136                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8            \N             45                     Romance
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# 610          \N             \N                       Drama
# ...         ...            ...                         ...
# 9320076      \N             57                 Documentary
# 9320103      \N            100                 Documentary
# 9320115      \N             \N                      Comedy
# 9320126      \N            116                          \N
# 9320136      \N             49                 Documentary
#
# [625185 rows x 9 columns]>

# %%
movies.drop(['isAdult', 'endYear', 'runtimeMinutes'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
movies.head()
# Out:
#         tconst titleType                 primaryTitle  \
# 8    tt0000009     movie                   Miss Jerry
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 587  tt0000591     movie             The Prodigal Son
# 610  tt0000615     movie           Robbery Under Arms
#
#                    originalTitle startYear                      genres
# 8                     Miss Jerry      1894                     Romance
# 498                     Bohemios      1905                          \N
# 570  The Story of the Kelly Gang      1906  Action,Adventure,Biography
# 587            L'enfant prodigue      1907                       Drama
# 610           Robbery Under Arms      1907                       Drama

# %%
print(movies['genres'].unique())
# Out:
# ['Romance' '\\N' 'Action,Adventure,Biography' ...
#  'Music,Musical,Reality-TV' 'Action,Crime,Short' 'News,Sport,Talk-Show']

# %%
print(movies['genres'].nunique())
# Out:
# 1470

# %%
movies_final = movies[movies['genres'] != "\\N"]
movies_final.drop(['titleType', 'originalTitle'], axis=1, inplace=True)
movies_final.reset_index()
movies_final.head()
# Out:
#         tconst                 primaryTitle startYear  \
# 8    tt0000009                   Miss Jerry      1894
# 570  tt0000574  The Story of the Kelly Gang      1906
# 587  tt0000591             The Prodigal Son      1907
# 610  tt0000615           Robbery Under Arms      1907
# 625  tt0000630                       Hamlet      1908
#
#                          genres
# 8                       Romance
# 570  Action,Adventure,Biography
# 587                       Drama
# 610                       Drama
# 625                       Drama

# %%
movies_final['genres'].nunique()
# Out:
# 1469

# %%
genres_separated = movies_final.groupby(['genres']).nunique()[['tconst']].reset_index()
genres_separated['genres'] = genres_separated.genres.apply(lambda genre: genre.split('/') and genre.split(','))
genres_separated = genres_separated.explode('genres')
genres_separated.groupby('genres').agg({'tconst':'sum'})
# Out:
#              tconst
# genres
# Action        52315
# Adult          8819
# Adventure     27335
# Animation      8606
# Biography     16658
# Comedy       106041
# Crime         35872
# Documentary  117234
# Drama        225199
# Family        17161
# Fantasy       14779
# Film-Noir       850
# Game-Show        27
# History       13820
# Horror        35329
# Music         11866
# Musical       10033
# Mystery       16269
# News           1441
# Reality-TV      487
# Romance       45942
# Sci-Fi        13413
# Short            57
# Sport          6822
# Talk-Show       163
# Thriller      42887
# War            9121
# Western        8098

# %%
condition_remove_some_genres = movies_final[((movies_final['genres'].str.contains('Film-Noir'))==False) & ((movies_final['genres'].str.contains('Game-Show'))==False) & ((movies_final['genres'].str.contains('News'))==False) & ((movies_final['genres'].str.contains('Reality-TV'))==False) & ((movies_final['genres'].str.contains('Short'))==False) & ((movies_final['genres'].str.contains('Talk-Show'))==False)]
condition_remove_some_genres
# Out:
#             tconst                                       primaryTitle  \
# 8        tt0000009                                         Miss Jerry
# 570      tt0000574                        The Story of the Kelly Gang
# 587      tt0000591                                   The Prodigal Son
# 610      tt0000615                                 Robbery Under Arms
# 625      tt0000630                                             Hamlet
# ...            ...                                                ...
# 9346727  tt9916620                                  The Copeland Case
# 9346728  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9346755  tt9916680  De la ilusión al desconcierto: cine colombiano...
# 9346767  tt9916706                                    Dankyavar Danka
# 9346788  tt9916754                     Chico Albuquerque - Revelações
#
#         startYear                      genres
# 8            1894                     Romance
# 570          1906  Action,Adventure,Biography
# 587          1907                       Drama
# 610          1907                       Drama
# 625          1908                       Drama
# ...           ...                         ...
# 9346727        \N                       Drama
# 9346728      2015                 Documentary
# 9346755      2007                 Documentary
# 9346767      2013                      Comedy
# 9346788      2013                 Documentary
#
# [551206 rows x 4 columns]

# %%
genres_separated2 = condition_remove_some_genres.groupby(['genres']).nunique()[['tconst']].reset_index()
genres_separated2['genres'] = genres_separated2.genres.apply(lambda genre: genre.split('/') and genre.split(','))
genres_separated2 = genres_separated2.explode('genres')
genres_separated2.groupby('genres').agg({'tconst':'sum'})
# Out:
#              tconst
# genres
# Action        52287
# Adult          8815
# Adventure     27272
# Animation      8598
# Biography     16538
# Comedy       105963
# Crime         35182
# Documentary  115773
# Drama        224282
# Family        17098
# Fantasy       14773
# History       13455
# Horror        35310
# Music         11833
# Musical       10030
# Mystery       16164
# Romance       45900
# Sci-Fi        13405
# Sport          6784
# Thriller      42812
# War            9097
# Western        8095

# %%
def func(single_genre, movie_genre):
    return single_genre in movie_genre

no_genre = 'Adult'
movie_gende_value_yes = 'Adult,Adventure,Romance'
movie_gende_value_no = 'Action,Adventure,Romance'
func(no_genre,movie_gende_value_no)
# Out:
# False

# %%
movies_final[movies_final['genres'] == 'News']
# Out:
#              tconst                                       primaryTitle  \
# 465000    tt0483983                         Entrevista Com o Surdo Gay
# 740850    tt0764869                                    Punyal na ginto
# 1022007  tt10097464                         Butch Hartman's OAXIS Plan
# 1022018  tt10097482  Butch Hartman's Cult of Personality: OAXIS Dis...
# 1428870   tt1082847                                   Ja en tenim prou
# 1499561  tt10954574                   Margaret Atwood: Live in Cinemas
# 2120088  tt12069158           KBEV/92nd Academy Awards - Full Coverage
# 2381070  tt12552184      Intelligence Community Abuses: The Interviews
# 2417079  tt12622258                          Brexit to be or not to be
# 2417410  tt12622858                                  The Best You Expo
# 2630835  tt13023416                                      Bindiya Verma
# 2843679  tt13416348                            XRCO Awards Nominations
# 2994751  tt13692932                                XRCO Awards Winners
# 3487259  tt14590688     Easter 2021 at Calvary Christian of Omaha area
# 4010640  tt15557864                           1990: Living on the edge
# 4022349  tt15579134              Ombres Chinoises au pays des Lumières
# 4325849  tt16233760  ABC News- As Detroit Suburb Burns Firefighters...
# 4348677  tt16279820                                     Austin Reentry
# 4429969  tt16442216               Stories We Tell the Fertility Secret
# 4492903   tt1672085  Max Trinitys Trickle Up Global Economics and t...
# 5126236  tt19847750                    Good evening Egypt - Radio Show
# 5250104  tt20448164  Making Baja California International Film Fest...
# 5250113  tt20448180  Making Baja California International Film Fest...
# 5250121  tt20448196  Making Baja California International Film Fest...
# 5349085   tt2097994                        Be a Millionaire with Ishah
# 5366031  tt21048424                                                  Y
# 5681107  tt22021004                    Inside a Cult - Gender Critical
# 5883943  tt23025386          Seattle, la ville où tout semble possible
# 5973636   tt2385113                                     Instrumentalis
# 6054096   tt2559950                         Montgomery Speaks His Mind
# 6054512   tt2561022                              The Lost Class of '59
# 6245535   tt3019342                        Top 10 Trends Spring Summer
# 6596097   tt3835130                                      En Nou Wij FF
# 6736472   tt4149460                                The Bullseye Killer
# 6874229   tt4458138                        Top 10 Trends Autumn Winter
# 7100384   tt4971710                                      Seisen sannen
# 7258119   tt5328118                                 Pathé News, No. 18
# 7275957   tt5368732                                      Vi de udsatte
# 7446927   tt5753798                                         Rain storm
# 7483560   tt5837950          Sensibilisation aux risques psychosociaux
# 7550083   tt5988034      Multiracial Identity for the Year 2000 Census
# 8445151   tt7967334                                           Bread me
# 8557748   tt8211964                         Myall Creek Day of Justice
# 8584807   tt8270726                   The Hurricane That Shook America
# 8741342   tt8611778                               Metamorfosi digitali
# 8855675   tt8864604            Burger King: with Michelle Trachtenberg
#
#         startYear genres
# 465000       2004   News
# 740850       1933   News
# 1022007      2018   News
# 1022018      2018   News
# 1428870      2007   News
# 1499561      2019   News
# 2120088      2020   News
# 2381070        \N   News
# 2417079      2018   News
# 2417410      2020   News
# 2630835        \N   News
# 2843679      2020   News
# 2994751      2020   News
# 3487259      2021   News
# 4010640      1990   News
# 4022349      2022   News
# 4325849      2015   News
# 4348677      2013   News
# 4429969      2021   News
# 4492903      2009   News
# 5126236      2017   News
# 5250104      2018   News
# 5250113      2019   News
# 5250121      2020   News
# 5349085      2011   News
# 5366031      2022   News
# 5681107      2022   News
# 5883943      2021   News
# 5973636      2012   News
# 6054096      1959   News
# 6054512      1959   News
# 6245535      2013   News
# 6596097      2013   News
# 6736472      2012   News
# 6874229      2014   News
# 7100384      1940   News
# 7258119      1919   News
# 7275957      2016   News
# 7446927      2015   News
# 7483560      2015   News
# 7550083      1998   News
# 8445151        \N   News
# 8557748        \N   News
# 8584807      2005   News
# 8741342      2016   News
# 8855675      1991   News

# %%
condition_remove_some_genres[condition_remove_some_genres['primaryTitle'] == 'Burger King: with Michelle Trachtenberg	']
# Out:
# Empty DataFrame
# Columns: [tconst, primaryTitle, startYear, genres]
# Index: []

# %%
condition_remove_some_genres.shape
# Out:
# (550326, 4)

# %%
title_ratings = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', sep = '\t')

# %%
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1920
# 1  tt0000002            5.8       260
# 2  tt0000003            6.5      1728
# 3  tt0000004            5.6       173
# 4  tt0000005            6.2      2541

# %%
title_ratings.shape
# Out:
# (1241487, 3)

# %%
movies_and_ratings = pd.merge(condition_remove_some_genres, title_ratings, on='tconst', how='left')
movies_and_ratings.head(10)
# Out:
#       tconst                    primaryTitle startYear  \
# 0  tt0000009                      Miss Jerry      1894
# 1  tt0000574     The Story of the Kelly Gang      1906
# 2  tt0000591                The Prodigal Son      1907
# 3  tt0000615              Robbery Under Arms      1907
# 4  tt0000630                          Hamlet      1908
# 5  tt0000675                     Don Quijote      1908
# 6  tt0000679  The Fairylogue and Radio-Plays      1908
# 7  tt0000886       Hamlet, Prince of Denmark      1910
# 8  tt0000941                  Locura de amor      1909
# 9  tt0001028                      Salome Mad      1909
#
#                        genres  averageRating  numVotes
# 0                     Romance            5.2     200.0
# 1  Action,Adventure,Biography            6.0     794.0
# 2                       Drama            5.1      20.0
# 3                       Drama            4.3      23.0
# 4                       Drama            2.9      25.0
# 5                       Drama            4.2      19.0
# 6           Adventure,Fantasy            5.2      66.0
# 7                       Drama            4.7      38.0
# 8                       Drama            4.5      23.0
# 9                      Comedy            4.1      17.0

# %%
movies_and_ratings.sort_values('averageRating', ascending=False)
# Out:
#             tconst                                       primaryTitle  \
# 523105   tt8215820  Are We Making a Film? Behind the Scenes: Follo...
# 297388  tt15481906                      Transilvania for Sierra Leone
# 388484   tt2720024                                  Journey 4 Artists
# 319216   tt1737585     East of Byzantium: War Gods and Warrior Saints
# 319149  tt17371496                              Meeting Mr. Christmas
# ...            ...                                                ...
# 551201   tt9916620                                  The Copeland Case
# 551202   tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 551203   tt9916680  De la ilusión al desconcierto: cine colombiano...
# 551204   tt9916706                                    Dankyavar Danka
# 551205   tt9916754                     Chico Albuquerque - Revelações
#
#        startYear                         genres  averageRating  numVotes
# 523105      2018                    Documentary           10.0       8.0
# 297388      2021                    Documentary           10.0      12.0
# 388484      2013  Biography,Documentary,History           10.0       7.0
# 319216      2016                    Documentary           10.0       9.0
# 319149      2022                        Romance           10.0       6.0
# ...          ...                            ...            ...       ...
# 551201        \N                          Drama            NaN       NaN
# 551202      2015                    Documentary            NaN       NaN
# 551203      2007                    Documentary            NaN       NaN
# 551204      2013                         Comedy            NaN       NaN
# 551205      2013                    Documentary            NaN       NaN
#
# [551206 rows x 6 columns]

# %%
movies_and_ratings['averageRating'].isna().sum()
# Out:
# 279883

# %%
movies_and_ratings.dropna(subset=['averageRating'], inplace = True)

# %%
movies_and_ratings['averageRating'].isna().sum()
# Out:
# 0

# %%
movies_and_ratings['numVotes'].isna().sum()
# Out:
# 0

# %%
movies_and_ratings
# Out:
#            tconst                 primaryTitle startYear  \
# 0       tt0000009                   Miss Jerry      1894
# 1       tt0000574  The Story of the Kelly Gang      1906
# 2       tt0000591             The Prodigal Son      1907
# 3       tt0000615           Robbery Under Arms      1907
# 4       tt0000630                       Hamlet      1908
# ...           ...                          ...       ...
# 551196  tt9916190                    Safeguard      2020
# 551197  tt9916270     Il talento del calabrone      2020
# 551198  tt9916362                        Coven      2020
# 551199  tt9916428          The Secret of China      2019
# 551200  tt9916538          Kuambil Lagi Hatiku      2019
#
#                             genres  averageRating  numVotes
# 0                          Romance            5.2     200.0
# 1       Action,Adventure,Biography            6.0     794.0
# 2                            Drama            5.1      20.0
# 3                            Drama            4.3      23.0
# 4                            Drama            2.9      25.0
# ...                            ...            ...       ...
# 551196   Action,Adventure,Thriller            3.6     238.0
# 551197                    Thriller            5.8    1370.0
# 551198               Drama,History            6.4    4959.0
# 551199       Adventure,History,War            3.8      14.0
# 551200                       Drama            8.3       6.0
#
# [270813 rows x 6 columns]

# %%
movies_and_ratings_five_percent = movies_and_ratings[movies_and_ratings['numVotes'] > 6096]

# %%
movies_and_ratings_five_percent.head()
# Out:
#          tconst                 primaryTitle startYear  \
# 626   tt0004972        The Birth of a Nation      1915
# 1527  tt0006864                  Intolerance      1916
# 3538  tt0009968              Broken Blossoms      1919
# 3784  tt0010323  The Cabinet of Dr. Caligari      1920
# 4413  tt0011237                    The Golem      1920
#
#                        genres  averageRating  numVotes
# 626         Drama,History,War            6.2   24930.0
# 1527            Drama,History            7.7   15699.0
# 3538            Drama,Romance            7.3   10442.0
# 3784  Horror,Mystery,Thriller            8.0   64403.0
# 4413           Fantasy,Horror            7.2    7834.0

# %%
movies_and_ratings_five_percent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13560 entries, 626 to 550867
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         13560 non-null  object
#  1   primaryTitle   13560 non-null  object
#  2   startYear      13560 non-null  object
#  3   genres         13560 non-null  object
#  4   averageRating  13560 non-null  float64
#  5   numVotes       13560 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 741.6+ KB

# %%
rotten_tomatoes_rating = pd.read_csv('https://raw.githubusercontent.com/Sebastiao199/Project3MRS/main/Rating%20RT.csv')
rotten_tomatoes_rating.drop(['Unnamed: 0'], axis=1, inplace=True)
rotten_tomatoes_rating
# Out:
#           tconst  tomatometer_rating
# 0      tt0343172                68.0
# 1      tt0031322                83.0
# 2      tt2316868                45.0
# 3      tt1166100                50.0
# 4      tt0449951                50.0
# ...          ...                 ...
# 11829  tt0488604                17.0
# 11830  tt2404738                86.0
# 11831  tt1572491                77.0
# 11832  tt0330602                32.0
# 11833  tt0221799                56.0
#
# [11834 rows x 2 columns]

# %%
imdb_rotten_merge = pd.merge(movies_and_ratings_five_percent, rotten_tomatoes_rating, on='tconst', how='left')
imdb_rotten_merge
# Out:
#           tconst                 primaryTitle startYear  \
# 0      tt0004972        The Birth of a Nation      1915
# 1      tt0006864                  Intolerance      1916
# 2      tt0009968              Broken Blossoms      1919
# 3      tt0010323  The Cabinet of Dr. Caligari      1920
# 4      tt0011237                    The Golem      1920
# ...          ...                          ...       ...
# 13564  tt9893250                 I Care a Lot      2020
# 13565  tt9894470                          VFW      2019
# 13566  tt9898858              Coffee & Kareem      2020
# 13567  tt9900782                       Kaithi      2019
# 13568  tt9907782                   The Cursed      2021
#
#                         genres  averageRating  numVotes  tomatometer_rating
# 0            Drama,History,War            6.2   24930.0                93.0
# 1                Drama,History            7.7   15699.0                97.0
# 2                Drama,Romance            7.3   10442.0                95.0
# 3      Horror,Mystery,Thriller            8.0   64403.0                 NaN
# 4               Fantasy,Horror            7.2    7834.0                 NaN
# ...                        ...            ...       ...                 ...
# 13564       Comedy,Crime,Drama            6.3  132724.0                 NaN
# 13565      Action,Crime,Horror            6.1    8565.0                81.0
# 13566      Action,Comedy,Crime            5.1   13807.0                20.0
# 13567   Action,Adventure,Crime            8.5   31848.0                 NaN
# 13568   Fantasy,Horror,Mystery            6.2   11143.0                 NaN
#
# [13569 rows x 7 columns]

# %%
imdb_rotten_merge['tomatometer_rating'].isna().sum()
# Out:
# 6612

# %%
type(imdb_rotten_merge['genres'][0])
# Out:
# str

# %%
imdb_rotten_merge['genres'] = imdb_rotten_merge['genres'].tolist()

# %%
type(imdb_rotten_merge['genres'][0])
# Out:
# str

# %%
imdb_rotten_merge['genresfinal'] = imdb_rotten_merge['genres'].apply(lambda x: x.split(','))
final_explosion_version = imdb_rotten_merge.explode('genresfinal').reset_index()
# movies_final.drop(['titleType', 'originalTitle'], axis=1, inplace=True)

# %%
final_explosion_version['startYear'] = final_explosion_version['startYear'].astype(str)
final_explosion_version['startYear'] = final_explosion_version['startYear'].apply(lambda x : x[0:4])
final_explosion_version['startYear'] = final_explosion_version['startYear'].apply(lambda x : int(x))
final_explosion_version['startYear']
# Out:
# 0        1915
# 1        1915
# 2        1915
# 3        1916
# 4        1916
#          ...
# 34292    2019
# 34293    2019
# 34294    2021
# 34295    2021
# 34296    2021
# Name: startYear, Length: 34297, dtype: int64

# %%
final_explosion_version
# Out:
#        index     tconst           primaryTitle  startYear  \
# 0          0  tt0004972  The Birth of a Nation       1915
# 1          0  tt0004972  The Birth of a Nation       1915
# 2          0  tt0004972  The Birth of a Nation       1915
# 3          1  tt0006864            Intolerance       1916
# 4          1  tt0006864            Intolerance       1916
# ...      ...        ...                    ...        ...
# 34292  13567  tt9900782                 Kaithi       2019
# 34293  13567  tt9900782                 Kaithi       2019
# 34294  13568  tt9907782             The Cursed       2021
# 34295  13568  tt9907782             The Cursed       2021
# 34296  13568  tt9907782             The Cursed       2021
#
#                        genres  averageRating  numVotes  tomatometer_rating  \
# 0           Drama,History,War            6.2   24930.0                93.0
# 1           Drama,History,War            6.2   24930.0                93.0
# 2           Drama,History,War            6.2   24930.0                93.0
# 3               Drama,History            7.7   15699.0                97.0
# 4               Drama,History            7.7   15699.0                97.0
# ...                       ...            ...       ...                 ...
# 34292  Action,Adventure,Crime            8.5   31848.0                 NaN
# 34293  Action,Adventure,Crime            8.5   31848.0                 NaN
# 34294  Fantasy,Horror,Mystery            6.2   11143.0                 NaN
# 34295  Fantasy,Horror,Mystery            6.2   11143.0                 NaN
# 34296  Fantasy,Horror,Mystery            6.2   11143.0                 NaN
#
#       genresfinal
# 0           Drama
# 1         History
# 2             War
# 3           Drama
# 4         History
# ...           ...
# 34292   Adventure
# 34293       Crime
# 34294     Fantasy
# 34295      Horror
# 34296     Mystery
#
# [34297 rows x 9 columns]

# %%
final_explosion_version.rename(columns = {'primaryTitle': 'Movie title', 
                                    'startYear': 'Year',
                                    'averageRating': 'IMDb rating',
                                    'tomatometer_rating': 'Rotten Tomatoes rating',
                                    'genresfinal': 'Genre',
                                    'genres': 'Genres',
                                    'numVotes': 'Nb votes'
                                    },
                         inplace = True)

# Director name 
# Movie title 
# Year
# IMDb rating

# %%
# final_table = imdb_rotten_merge[imdb_rotten_merge['genres'].apply(lambda genre: genre.split(',')).explode()]

# %%
final_explosion_version
# Out:
#        index     tconst            Movie title  Year                  Genres  \
# 0          0  tt0004972  The Birth of a Nation  1915       Drama,History,War
# 1          0  tt0004972  The Birth of a Nation  1915       Drama,History,War
# 2          0  tt0004972  The Birth of a Nation  1915       Drama,History,War
# 3          1  tt0006864            Intolerance  1916           Drama,History
# 4          1  tt0006864            Intolerance  1916           Drama,History
# ...      ...        ...                    ...   ...                     ...
# 34292  13567  tt9900782                 Kaithi  2019  Action,Adventure,Crime
# 34293  13567  tt9900782                 Kaithi  2019  Action,Adventure,Crime
# 34294  13568  tt9907782             The Cursed  2021  Fantasy,Horror,Mystery
# 34295  13568  tt9907782             The Cursed  2021  Fantasy,Horror,Mystery
# 34296  13568  tt9907782             The Cursed  2021  Fantasy,Horror,Mystery
#
#        IMDb rating  Nb votes  Rotten Tomatoes rating      Genre
# 0              6.2   24930.0                    93.0      Drama
# 1              6.2   24930.0                    93.0    History
# 2              6.2   24930.0                    93.0        War
# 3              7.7   15699.0                    97.0      Drama
# 4              7.7   15699.0                    97.0    History
# ...            ...       ...                     ...        ...
# 34292          8.5   31848.0                     NaN  Adventure
# 34293          8.5   31848.0                     NaN      Crime
# 34294          6.2   11143.0                     NaN    Fantasy
# 34295          6.2   11143.0                     NaN     Horror
# 34296          6.2   11143.0                     NaN    Mystery
#
# [34297 rows x 9 columns]

# %%
final_explosion_version.sort_values(by=["IMDb rating"], ascending=False).head(50)
# Out:
#        index      tconst                                        Movie title  \
# 24429   9667  tt16747572                            The Silence of Swastika
# 24430   9667  tt16747572                            The Silence of Swastika
# 8697    3524   tt0111161                           The Shawshank Redemption
# 2954    1226   tt0068646                                      The Godfather
# 2953    1226   tt0068646                                      The Godfather
# 12707   5081   tt0252487                                    The Chaos Class
# 12706   5081   tt0252487                                    The Chaos Class
# 12880   5152   tt0259534                Ramayana: The Legend of Prince Rama
# 12879   5152   tt0259534                Ramayana: The Legend of Prince Rama
# 12878   5152   tt0259534                Ramayana: The Legend of Prince Rama
# 27574  10916   tt2592910                             CM101MMXI Fundamentals
# 27575  10916   tt2592910                             CM101MMXI Fundamentals
# 23543   9320  tt15327088                                            Kantara
# 23542   9320  tt15327088                                            Kantara
# 23541   9320  tt15327088                                            Kantara
# 8154    3315   tt0108052                                   Schindler's List
# 8156    3315   tt0108052                                   Schindler's List
# 8155    3315   tt0108052                                   Schindler's List
# 11528   4618   tt0167260      The Lord of the Rings: The Return of the King
# 11529   4618   tt0167260      The Lord of the Rings: The Return of the King
# 1302     524   tt0050083                                       12 Angry Men
# 1303     524   tt0050083                                       12 Angry Men
# 3240    1341   tt0071562                              The Godfather Part II
# 11530   4618   tt0167260      The Lord of the Rings: The Return of the King
# 31085  12296   tt5354160                                        Mirror Game
# 24246   9595  tt16492678  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...
# 24247   9595  tt16492678  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...
# 24248   9595  tt16492678  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...
# 31083  12296   tt5354160                                        Mirror Game
# 31084  12296   tt5354160                                        Mirror Game
# 3241    1341   tt0071562                              The Godfather Part II
# 17295   6860   tt0468569                                    The Dark Knight
# 17294   6860   tt0468569                                    The Dark Knight
# 17293   6860   tt0468569                                    The Dark Knight
# 21315   8442  tt11989890           David Attenborough: A Life on Our Planet
# 12759   5105   tt0253828                                         Tosun Pasa
# 32843  12981   tt7391996                                  C/o Kancharapalem
# 21316   8442  tt11989890           David Attenborough: A Life on Our Planet
# 12758   5105   tt0253828                                         Tosun Pasa
# 29732  11764   tt4139928                           The Legend of Maula Jatt
# 32898  13004   tt7466810                                        777 Charlie
# 8648    3506   tt0110912                                       Pulp Fiction
# 30994  12259   tt5275892                              O.J.: Made in America
# 29731  11764   tt4139928                           The Legend of Maula Jatt
# 8649    3506   tt0110912                                       Pulp Fiction
# 30995  12259   tt5275892                              O.J.: Made in America
# 23427   9270  tt15097216                                           Jai Bhim
# 29733  11764   tt4139928                           The Legend of Maula Jatt
# 12391   4952   tt0237376                                           Kireedam
# 3554    1468   tt0075143                                        The Message
#
#        Year                       Genres  IMDb rating   Nb votes  \
# 24429  2021          Documentary,History          9.7    10141.0
# 24430  2021          Documentary,History          9.7    10141.0
# 8697   1994                        Drama          9.3  2656994.0
# 2954   1972                  Crime,Drama          9.2  1841519.0
# 2953   1972                  Crime,Drama          9.2  1841519.0
# 12707  1975                 Comedy,Drama          9.2    40813.0
# 12706  1975                 Comedy,Drama          9.2    40813.0
# 12880  1993   Action,Adventure,Animation          9.2     7624.0
# 12879  1993   Action,Adventure,Animation          9.2     7624.0
# 12878  1993   Action,Adventure,Animation          9.2     7624.0
# 27574  2013           Comedy,Documentary          9.1    46359.0
# 27575  2013           Comedy,Documentary          9.1    46359.0
# 23543  2022       Action,Adventure,Drama          9.1    59858.0
# 23542  2022       Action,Adventure,Drama          9.1    59858.0
# 23541  2022       Action,Adventure,Drama          9.1    59858.0
# 8154   1993      Biography,Drama,History          9.0  1345913.0
# 8156   1993      Biography,Drama,History          9.0  1345913.0
# 8155   1993      Biography,Drama,History          9.0  1345913.0
# 11528  2003       Action,Adventure,Drama          9.0  1831937.0
# 11529  2003       Action,Adventure,Drama          9.0  1831937.0
# 1302   1957                  Crime,Drama          9.0   784476.0
# 1303   1957                  Crime,Drama          9.0   784476.0
# 3240   1974                  Crime,Drama          9.0  1261658.0
# 11530  2003       Action,Adventure,Drama          9.0  1831937.0
# 31085  2016       Crime,Mystery,Thriller          9.0    27084.0
# 24246  2021     Action,Animation,Fantasy          9.0    13255.0
# 24247  2021     Action,Animation,Fantasy          9.0    13255.0
# 24248  2021     Action,Animation,Fantasy          9.0    13255.0
# 31083  2016       Crime,Mystery,Thriller          9.0    27084.0
# 31084  2016       Crime,Mystery,Thriller          9.0    27084.0
# 3241   1974                  Crime,Drama          9.0  1261658.0
# 17295  2008           Action,Crime,Drama          9.0  2629679.0
# 17294  2008           Action,Crime,Drama          9.0  2629679.0
# 17293  2008           Action,Crime,Drama          9.0  2629679.0
# 21315  2020        Biography,Documentary          8.9    32187.0
# 12759  1976               Comedy,History          8.9    23438.0
# 32843  2018                        Drama          8.9     7120.0
# 21316  2020        Biography,Documentary          8.9    32187.0
# 12758  1976               Comedy,History          8.9    23438.0
# 29732  2022         Action,Drama,Fantasy          8.9     7476.0
# 32898  2022       Adventure,Comedy,Drama          8.9    29079.0
# 8648   1994                  Crime,Drama          8.9  2033655.0
# 30994  2016  Biography,Crime,Documentary          8.9    20038.0
# 29731  2022         Action,Drama,Fantasy          8.9     7476.0
# 8649   1994                  Crime,Drama          8.9  2033655.0
# 30995  2016  Biography,Crime,Documentary          8.9    20038.0
# 23427  2021          Crime,Drama,Mystery          8.9   200400.0
# 29733  2022         Action,Drama,Fantasy          8.9     7476.0
# 12391  1989                 Action,Drama          8.9     7775.0
# 3554   1976      Biography,Drama,History          8.9     9431.0
#
#        Rotten Tomatoes rating        Genre
# 24429                     NaN  Documentary
# 24430                     NaN      History
# 8697                     91.0        Drama
# 2954                     98.0        Drama
# 2953                     98.0        Crime
# 12707                     NaN        Drama
# 12706                     NaN       Comedy
# 12880                     NaN    Animation
# 12879                     NaN    Adventure
# 12878                     NaN       Action
# 27574                     NaN       Comedy
# 27575                     NaN  Documentary
# 23543                     NaN        Drama
# 23542                     NaN    Adventure
# 23541                     NaN       Action
# 8154                     97.0    Biography
# 8156                     97.0      History
# 8155                     97.0        Drama
# 11528                    93.0       Action
# 11529                    93.0    Adventure
# 1302                      NaN        Crime
# 1303                      NaN        Drama
# 3240                      NaN        Crime
# 11530                    93.0        Drama
# 31085                     NaN     Thriller
# 24246                     NaN       Action
# 24247                     NaN    Animation
# 24248                     NaN      Fantasy
# 31083                     NaN        Crime
# 31084                     NaN      Mystery
# 3241                      NaN        Drama
# 17295                    94.0        Drama
# 17294                    94.0        Crime
# 17293                    94.0       Action
# 21315                     NaN    Biography
# 12759                     NaN      History
# 32843                     NaN        Drama
# 21316                     NaN  Documentary
# 12758                     NaN       Comedy
# 29732                     NaN        Drama
# 32898                     NaN        Drama
# 8648                     92.0        Crime
# 30994                     NaN        Crime
# 29731                     NaN       Action
# 8649                     92.0        Drama
# 30995                     NaN  Documentary
# 23427                     NaN      Mystery
# 29733                     NaN      Fantasy
# 12391                     NaN        Drama
# 3554                      NaN    Biography

# %%
final_explosion_version['Rotten Tomatoes rating'] = final_explosion_version['Rotten Tomatoes rating']/10
final_explosion_version['Rotten Tomatoes rating'].head(20)
# Out:
# 0     9.3
# 1     9.3
# 2     9.3
# 3     9.7
# 4     9.7
# 5     9.5
# 6     9.5
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: Rotten Tomatoes rating, dtype: float64

# %%
final_explosion_version.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34297 entries, 0 to 34296
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   34297 non-null  int64
#  1   tconst                  34297 non-null  object
#  2   Movie title             34297 non-null  object
#  3   Year                    34297 non-null  int64
#  4   Genres                  34297 non-null  object
#  5   IMDb rating             34297 non-null  float64
#  6   Nb votes                34297 non-null  float64
#  7   Rotten Tomatoes rating  17844 non-null  float64
#  8   Genre                   34297 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.4+ MB

# %%
final_explosion_version.to_csv('GenreQuestion.csv')

# %%
francisco_table = pd.read_csv('https://raw.githubusercontent.com/Sebastiao199/Project3MRS/main/tprn_10.csv')
francisco_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68498 entries, 0 to 68497
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   68498 non-null  int64
#  1   tconst       68498 non-null  object
#  2   Movie title  68498 non-null  object
#  3   Year         68498 non-null  int64
#  4   Genres       68498 non-null  object
#  5   nconst       68491 non-null  object
#  6   category     68491 non-null  object
#  7   IMDb rating  68498 non-null  float64
#  8   Nb votes     68498 non-null  float64
#  9   Staff name   68485 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 5.2+ MB

# %%
francisco_table['Movie title'].nunique()
# Out:
# 13016
